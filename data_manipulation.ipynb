# %%
import pandas as pd

# %%
#define base study birds cluster
d = {
    "species": [
        "European pied flycatcher",
        "Spotted flycatcher",
        "Collared flycatcher",
        "Wood warbler",
        "Willow warbler",
        "Common Redstart",
        "Brambling",
        "Eurasian Siskin",
        "Blackcap",
        "Wood Pigeon",
        "European pied flycatcher",
        "Spotted flycatcher",
        "Collared flycatcher",
        "Wood warbler",
        "Willow warbler",
        "Common Redstart",
        "Brambling",
        "Eurasian Siskin",
        "Blackcap",
        "Wood Pigeon"
    ]
}

#convert into an dataframe
df = pd.DataFrame(data = d)

# %%
#export dataframe into an .csv file
df.to_csv('dataBase', index = True)

# %%
#add forest/non-forest reliant species label
#as forest_label
#1 - forest_dep 
#0 - non_forest_dep
data_base = 'dataBase'
df = pd.read_csv(data_base)

forest_dependent = [
    "European pied flycatcher",
    "Spotted flycatcher",
    "Collared flycatcher",
    "Wood warbler",
    "Willow warbler",
    "Common Redstart",
    "Brambling",
    "Eurasian Siskin",
    "Blackcap",
    "Wood Pigeon"
]

non_forest_dependent = [
    "Northern Lapwing",
    "Eurasian Curlew",
    "Black-tailed Godwit",
    "Barn Swallow",
    "Common House Martin",
    "European Golden Plover",
    "White Stork",
    "Common Cuckoo",
    "Common Swift",
    "Eurasian Hoopoe"
]

#add the label caterogry
df['forest_label'] = None

#add the coordinates
df['latitude'] = None
df['longitude'] = None

#add indices values
df['ndwi'] = None
df['mndwi'] = None
df['ndbi'] = None
df['ndvi'] = None

#recreate de csv file
df.to_csv(data_base, index = False)
